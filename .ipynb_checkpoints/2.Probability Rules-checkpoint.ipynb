# %% [markdown]
# Remember that ;
#
# * A random experiment is any process for which we can't predict outcomes with certainty.
# * An outcome is a possible result of a random experiment, while
# * An event can include more than one outcome.

# %% [markdown]
# In probability theory, the outcomes of a random experiment are usually represented as a **set**. For example, this is how we can represent the outcomes of a die roll as a set:
#
# $$Outcomes = \{1,2,3,4,5,6\}$$

# %% [markdown]
# A set is a collection of distinct objects, which means each outcome must occur only once in a set. In probability theory, the set of all possible outcomes is called a **sample space**. A sample space is often denoted by the capital Greek letter **Ω** (read **omega**). This is how we represent the sample space of a die roll
#
# $$Ω = \{1,2,3,4,5,6\}$$

# %%
# We toss a normal coin two times. Find the sample space of this experiment

coin_toss_omega = {"HH", "HT", "TH","TT"}

# %% [markdown]
# Consider the event **getting an even number when rolling a die**, which we abbreviate by the letter **E**.
#
# `E = {2,4,6}`

# %% [markdown]
# We assign the probability to events, not outcomes. For our event E, we have:
#
# `P(E) = P({2,4,6}) = number of successful Outcome/number of possible outcome = 3/6 = 0.5`

# %% [markdown]
# Consider a random experiment where we roll a fair six-sided die two times (**fair** means all outcomes have equal chances of occurring). The sample space of this experiment has 36 possible outcomes (all the sequences of numbers we can get from the two throws)
#
# $$Ω=\{(1,1),(1,2),(1,3)....,(3,1),(3,2).....,(6,5),(6,6)\}$$

# %%
# find the probability of the following events:

# The sum of the two rolls is 6

p_sum_6 = 5/36 # sucessfull outcomes (1,5),(2,4),(3,3),(4,2),(5,1)

# The sum of the two rolls is lower than 15

p_lower_15 = 36/36

# The sum of the two rolls is greater than 13.

p_greater_13 = 0/36

# %% [markdown]
# We see no dice combination results in a sum greater than 12 (we'll denote this event by **A**), which means event A is impossible and has no corresponding outcome in the sample space. Thus, event A corresponds to an empty set, which we denote by the symbol **Ø** :

# %% [markdown]
# $$A = \{\} = Ø$$

# %% [markdown]
# The probability of A, which is an impossible event, is 0
#
# `P(A) = P(Ø) = number of successful Outcome/number of possible outcome = 0/36 = 0`

# %% [markdown]
# We also see all dice combinations result in a sum that is 15 or lower(we'll denote this event by **B**), which means event B is certain to happen and contains all the elements of the sample space **Ω**
#
# `P(B) = P(Ω) = number of successful Outcome/number of possible outcome = 36/36 = 1`

# %% [markdown]
# **--------------------------------------------------------------------------------------------------------------------------**

# %%
from IPython.display import Image
Image("Probablity.JPG")

# %% [markdown]
# Above are three important probability rules that we'll need to always keep in mind while we're solving probability problems.

# %%
# sum is either 2 or 4
p_2_or_4 = 4/36 # sucessfull outcomes (1,1),(1,3,),(2,2),(3,1)

# The sum is either 12 or 13

p_12_or_13 = 1/36 # sucessfull outcomes (6,6)

# %% [markdown]
# Consider the following two events, A and B:
#
# A — getting a `3`
#
# B — getting a `5`
#
# P(A or B) = 2/6
#
# To calculate P(A or B), we can also use the formula below, which is sometimes called the **addition rule**
#
#  P(A or B) = P(A) + P(B)  = 1/6+1/6 = 2/6
#
# The addition rule can be extended to more than two events

# %%
# Using the addition rule, find the probability

# The sum is either 5 or 9

p_5_or_9 = 4/36 + 4/36 # (1,4),(2,3),(3,2),(4,1)----------(3,6),(4,5),(5,4),(6,3)

# The sum is either even or less than 2

p_even_or_less_2 = 18/36+0/36 # (1,1),(1,3),(1,5),(2,2),(2,4),(2,6),(3,1),(3,3),(3,5),(4,2),(4,4),(4,6),(5,1),(5,3),(5,5),(6,2),(6,4),(6,6)

# The sum is either 4 or a multiple of 3 

p_4_or_3_multiple =3/36+12/36 # (1,3),(2,2),(3,1) -------(1,2),(1,5),(2,1),(2,4),(3,3),(3,6),(4,2),(4,5),(5,1),(5,4),(6,3),(6,6)

# %% [markdown]
# Consider;
#
# A = {3} — getting a 3
#
# B= {5} — getting a 5
#
# In probability, we can visualize events using Venn diagrams. For instance, this is how we can represent event A on a Venn diagram:

# %%
Image("Probablity1.JPG")

# %% [markdown]
# Notice we represented A as a green circle inside a rectangle. The rectangle describes the entire sample space. We can also add events A and B on the same Venn diagram:

# %%
Image("Probablity2.JPG")

# %% [markdown]
# Consider also the events C and D, which are:
#
# C = {2,4,6} — getting an even number
#
# D = {4,5,6} — getting a number greater than 3

# %% [markdown]
# Notice that two elements, 4 and 6, belong to both C and D. To account for these two common elements, we need to represent C and D on a Venn diagram with a point of intersection:

# %%
Image("Probablity3.JPG")

# %%
# considering a single die

p_c = 3/6

p_d = 3/6

# %%
# P(C or D) using the addition rule considering single die
p_c_d_addition = p_c + p_d  


# Using theoretical probability formula
p_c_d_formula = 4/6 # set of successfull outcome 2,4,6,5

print(p_c_d_addition)
print(p_c_d_formula)
# Out:
# 1.0
# 0.6666666666666666

# %% [markdown]
# We used two different ways to calculate `P(C or D)`, and we expected both to lead to the same result.`

# %% [markdown]
# The reason we got different results is that the addition rule doesn't work for events that share corresponding outcomes. In the case of C and D, they have two outcomes in common: `4` and `6`

# %% [markdown]
# To understand why the addition rule doesn't work, let's visualize events C and D on a Venn diagram again.

# %%
Image("Probablity4.JPG")

# %% [markdown]
# When we do P(C) + P(D),we add up the intersection point (the shaded area) twice:

# %%
Image("Probablity5.JPG")

# %% [markdown]
# To solve the problem, we need to subtract the probability of the shaded area such that we add it only once:

# %%
Image("Probablity6.JPG")

# %% [markdown]
# The shaded area is the point where C and D intersect, which means it's the event where both C and D happen. This corresponds to the event **getting a number that is both even and greater than 3**, which has the probability:
#
# `P(C and D) = 2/6`
#
# `Subtracting P(C and D) from P(C) + p(D), we get: 3/6+3/6-2/6 = 4/6`
#
# `P(C or D) = 4/6`

# %%
'''An online betting company offers customers the possibility of betting 
on a variety of games and events(football, tennis, hockey, horse races, 
car races, etc.). Based on historical data, the company knows the 
empirical probabilities of the following events:

Event F (a new customer's first bet is on football) — the probability is 0.26.
Event T (a new customer's first bet is on tennis) — the probability is 0.11.
Event "T and F" (a new customer's first bet is on both football and tennis)
— the probability is 0.03.'''

# probability that a new customer's first bet is either on football or tennis.

p_f_or_t = 0.26+.11-0.03
p_f_or_t
# Out:
# 0.33999999999999997

# %% [markdown]
# We saw on our Venn diagrams we have two types of events:
#
# * Events that don't intersect at all (like A and B).
# * Events that have an area where they intersect (like C and D).

# %% [markdown]
# Events that don't intersect are called **mutually exclusive** — events A and B are mutually exclusive. If two events are mutually exclusive, it means they can't happen both at the same time
#
# * Getting a 5 (event one) and getting a 3 (event two) when we roll a regular six-sided die — it's impossible to get both a 5 and 3.
# * A coin lands on heads (event one) and tails (event two) — it's impossible for a coin to land on both heads and tails.

# %% [markdown]
# Events that intersect are called mutually **non-exclusive** — events C and D on the Venn diagram above are mutually non-exclusive. Mutually non-exclusive events can happen at the same time

# %% [markdown]
# * Getting a number greater than 2 (event one) and getting an odd number (event two) when we roll a regular six-sided die — we could get a 5, which is both greater than 2 (event one) and odd (event two).
# * A customer buys a red shirt (event one) and a blue shirt (event two) — the customer can buy both a red shirt (event one) and a blue shirt (event two).

# %% [markdown]
# For mutually non-exclusive events, we always need to use the formula below to make sure we don't include the area of intersection twice in our calculations
#
# $$P(A or B) = P(A) + P(B) - P(A and B)$$

# %% [markdown]
# The formula above, however, works for both **mutually non-exclusive** and **exclusive** events.
# * If two events — A and B — are mutually exclusive, then the event **A and B** is impossible .
# * If event **A and B** is impossible, it means  `𝑃(𝐴𝑎𝑛𝑑𝐵) = 0`

# %% [markdown]
# $$𝑃(𝐴𝑜𝑟𝐵)=𝑃(𝐴)+𝑃(𝐵)−0$$
#
# $$𝑃(𝐴𝑜𝑟𝐵)=𝑃(𝐴)+𝑃(𝐵)$$

# %%
"""Based on historical data, the company knows the empirical probabilities 
of the following events:

- Event H (a new customer's first bet is on hockey) — the probability is 0.08.
- Event C (a new customer's first bet is on car races) — the probability is 0.11.
- Event "H or C" (a new customer's first bet is either on hockey or car races) 
— the probability is 0.17."""

#  probability that a new customer's first bet is on both hockey and car

p_h_and_c = .08+.011-.017
p_h_and_c
# Out:
# 0.074

# %% [markdown]
# Taken individually, event A and event B are sets containing a series of outcomes. In set theory, when we say **set A or set B**, we are referring to a single set that is the result of the **union** between set A and set B. The resulting set will have:
#
# * The elements of set A that are not in B
# * The elements of set B that are not in A
# * The elements that occur in both A and B

# %% [markdown]
# A set can only contain unique elements, so the set resulting from a union cannot include the elements that occur in both A and B more than one time.

# %% [markdown]
# When we say **set A and set B**, we are referring to a single set that contains all the unique elements that occur in both A and B. In set theory, this **and** operation is called **intersection** and is represented by the symbol **Π**.

# %% [markdown]
# so
#
# **(A or B) become (A U B)** ,
#
# **(A and B) become (A Π B )**

# %% [markdown]
# **P(A U B) = P(A) + P(B) - (A Π B )**

# %% [markdown]
# Note that Probablity of any Event ranges between 0 to 1
